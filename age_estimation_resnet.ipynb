# %%
# %cd /content/drive/MyDrive/age_reference
# Out:
# /content/drive/MyDrive/age_reference

# %%
# !git clone https://github.com/yu4u/age-estimation-pytorch
# Out:
# Cloning into 'age-estimation-pytorch'...
# remote: Enumerating objects: 36, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 36 (delta 3), reused 1 (delta 0), pack-reused 24
# Receiving objects: 100% (36/36), 1.25 MiB | 14.88 MiB/s, done.
# Resolving deltas: 100% (8/8), done.

# %%
# !wget http://158.109.8.102/AppaRealAge/appa-real-release.zip
# !unzip appa-real-release.zip

# %%
# !pip install better_exceptions

# %%
# !pip install pretrainedmodels

# %%
# !pip install yacs

# %%
# !python ./age-estimation-pytorch//train.py --data_dir /content/drive/MyDrive/age_reference/appa-real-release --tensorboard tf_log MODEL.ARCH resnet50 TRAIN.OPT sgd TRAIN.LR 0.1
# Out:
# 2023-12-18 04:56:59.382832: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-18 04:56:59.382887: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-18 04:56:59.384198: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-18 04:56:59.391226: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !pip install tensorboard

# %%
# !tensorboard --logdir /content/age-estimation-pytorch/tf_log
# Out:
# 2023-12-16 12:30:43.871614: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-16 12:30:43.871696: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-16 12:30:43.875131: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-16 12:30:43.889522: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python demo.py --img_dir /content/age-estimation-pytorch/appa-real-release
# Out:
# => creating model 'se_resnext50_32x4d'
# => model path is not set; start downloading trained model to /content/age-estimation-pytorch/misc/epoch044_0.02343_3.9984.pth
# => download finished
# => loading checkpoint '/content/age-estimation-pytorch/misc/epoch044_0.02343_3.9984.pth'
# => loaded checkpoint '/content/age-estimation-pytorch/misc/epoch044_0.02343_3.9984.pth'

# %%
# !python ./age-estimation-pytorch/test.py --data_dir /content/drive/MyDrive/age_reference/appa-real-release --resume /content/drive/MyDrive/age_reference/checkpoint/epoch039_0.02573_5.2715.pth MODEL.ARCH resnet50
# Out:
# 2023-12-18 05:54:14.199639: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-18 05:54:14.199696: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-18 05:54:14.201635: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-18 05:54:15.937247: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# => creating model 'resnet50'
# ...

# %%
import torch
model = torch.load('/content/drive/MyDrive/age_reference/checkpoint/epoch041_0.02518_5.0384.pth', map_location=torch.device('cpu'))

# %%
model['state_dict']
# Out:
# OrderedDict([('conv1.weight',
#               tensor([[[[ 2.7753e-02,  2.5479e-02, -5.2760e-03,  ..., -9.8976e-03,
#                          -1.5626e-02, -6.4415e-02],
#                         [ 2.0709e-02,  1.5694e-02,  1.7125e-02,  ...,  1.1230e-02,
#                          -7.6857e-03, -3.3362e-02],
#                         [ 4.3242e-02,  2.3845e-02,  1.5615e-02,  ...,  9.8884e-02,
#                           5.8823e-02,  6.5495e-02],
#                         ...,
#                         [-5.2647e-03,  2.3020e-02, -2.1517e-02,  ..., -1.3487e-01,
#                          -6.3778e-02,  2.7392e-02],
#                         [ 1.4220e-02,  5.6039e-02,  7.1207e-02,  ...,  5.0133e-02,
#                           4.9086e-03,  2.1360e-02],
#                         [-4.8678e-02, -8.5333e-03,  2.1784e-02,  ...,  7.4496e-02,
#                           5.7476e-02,  3.8313e-02]],
#
#                        [[-1.3417e-02,  1.1961e-02,  2.5223e-02,  ...,  8.5838e-02,
# ...
